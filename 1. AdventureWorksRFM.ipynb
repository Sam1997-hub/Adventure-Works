# %%
import numpy as np
import pandas as pd

# %%
customer=pd.read_csv('AdventureWorks Customer Lookup.csv',encoding='ISO-8859-1')

# %%
customer['name'] = customer['FirstName'] + ' ' + customer['LastName']

# %%
customer.dropna(inplace=True)

# %%
customer.drop(['FirstName','LastName','Prefix'],axis=1,inplace=True)

# %%
sales_2020=pd.read_csv('AdventureWorks Sales Data 2020.csv')

# %%
sales_2021=pd.read_csv('AdventureWorks Sales Data 2021.csv')

# %%
sales_2022=pd.read_csv('AdventureWorks Sales Data 2022.csv')

# %%
sales_data=pd.concat([sales_2020,sales_2021,sales_2022],ignore_index=True)

# %%
sales_data
# Out:
#         OrderDate   StockDate OrderNumber  ProductKey  CustomerKey  \
# 0      2020-01-01  2019-09-21     SO45080         332        14657
# 1      2020-01-01  2019-12-05     SO45079         312        29255
# 2      2020-01-01  2019-10-29     SO45082         350        11455
# 3      2020-01-01  2019-11-16     SO45081         338        26782
# 4      2020-01-02  2019-12-15     SO45083         312        14947
# ...           ...         ...         ...         ...          ...
# 56041  2022-06-30  2022-03-22     SO74143         477        28517
# 56042  2022-06-30  2022-03-15     SO74143         479        28517
# 56043  2022-06-30  2022-04-08     SO74143         606        28517
# 56044  2022-06-30  2022-05-15     SO74124         480        21676
# 56045  2022-06-30  2022-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity
# 0                 1              1              1
# 1                 4              1              1
# 2                 9              1              1
# 3                 6              1              1
# 4                10              1              1
# ...             ...            ...            ...
# 56041            10              3              2
# 56042            10              2              1
# 56043            10              1              1
# 56044             7              2              2
# 56045             7              1              2
#
# [56046 rows x 8 columns]

# %%
existing_customer=sales_data.groupby('CustomerKey').agg(CustomerComeback=('OrderNumber',lambda x:x.count())).reset_index()
existing_customer
# Out:
#        CustomerKey  CustomerComeback
# 0            11000                 7
# 1            11001                10
# 2            11002                 3
# 3            11003                 8
# 4            11004                 5
# ...            ...               ...
# 17411        29479                 1
# 17412        29480                 5
# 17413        29481                 1
# 17414        29482                 1
# 17415        29483                 1
#
# [17416 rows x 2 columns]

# %%
 existing_customer['ReturnCustomer']=np.where(existing_customer['CustomerComeback']>1,"Yes","No")

# %%
existing_customer
# Out:
#        CustomerKey  CustomerComeback ReturnCustomer
# 0            11000                 7            Yes
# 1            11001                10            Yes
# 2            11002                 3            Yes
# 3            11003                 8            Yes
# 4            11004                 5            Yes
# ...            ...               ...            ...
# 17411        29479                 1             No
# 17412        29480                 5            Yes
# 17413        29481                 1             No
# 17414        29482                 1             No
# 17415        29483                 1             No
#
# [17416 rows x 3 columns]

# %%
sales_data['OrderDate']=pd.to_datetime(sales_data['OrderDate'])

# %%
sales_data['StockDate']=pd.to_datetime(sales_data['StockDate'])

# %%
max_date=pd.to_datetime(sales_data['OrderDate'].max())

# %%
product_table=pd.read_csv('AdventureWorks Product Lookup.csv')

# %%
sales_data.columns
# Out:
# Index(['OrderDate', 'StockDate', 'OrderNumber', 'ProductKey', 'CustomerKey',
#        'TerritoryKey', 'OrderLineItem', 'OrderQuantity'],
#       dtype='object')

# %%
product_table.columns
# Out:
# Index(['ProductKey', 'ProductSubcategoryKey', 'ProductSKU', 'ProductName',
#        'ModelName', 'ProductDescription', 'ProductColor', 'ProductSize',
#        'ProductStyle', 'ProductCost', 'ProductPrice'],
#       dtype='object')

# %%
sales_data=sales_data.merge(product_table,how='inner',on='ProductKey').drop(['ProductSubcategoryKey', 'ProductSKU', 'ProductName',
       'ModelName', 'ProductDescription', 'ProductColor', 'ProductSize',
       'ProductStyle'],axis=1)

# %%
sales_data
# Out:
#        OrderDate  StockDate OrderNumber  ProductKey  CustomerKey  \
# 0     2020-01-01 2019-09-21     SO45080         332        14657
# 1     2020-01-01 2019-12-05     SO45079         312        29255
# 2     2020-01-01 2019-10-29     SO45082         350        11455
# 3     2020-01-01 2019-11-16     SO45081         338        26782
# 4     2020-01-02 2019-12-15     SO45083         312        14947
# ...          ...        ...         ...         ...          ...
# 56041 2022-06-30 2022-03-22     SO74143         477        28517
# 56042 2022-06-30 2022-03-15     SO74143         479        28517
# 56043 2022-06-30 2022-04-08     SO74143         606        28517
# 56044 2022-06-30 2022-05-15     SO74124         480        21676
# 56045 2022-06-30 2022-05-04     SO74124         538        21676
#
#        TerritoryKey  OrderLineItem  OrderQuantity  ProductCost  ProductPrice
# 0                 1              1              1     413.1463      699.0982
# 1                 4              1              1    2171.2942     3578.2700
# 2                 9              1              1    1898.0944     3374.9900
# 3                 6              1              1     413.1463      699.0982
# 4                10              1              1    2171.2942     3578.2700
# ...             ...            ...            ...          ...           ...
# 56041            10              3              2       1.8663        4.9900
# 56042            10              2              1       3.3623        8.9900
# 56043            10              1              1     343.6496      539.9900
# 56044             7              2              2       0.8565        2.2900
# 56045             7              1              2       8.0373       21.4900
#
# [56046 rows x 10 columns]

# %%
rfm=sales_data.groupby('CustomerKey').agg(recency=('OrderDate',lambda x : (max_date-x.max()).days),frequency=('OrderNumber','count'),monetary=('ProductPrice',lambda x:x.sum())).reset_index()

# %%
rfm
# Out:
#        CustomerKey  recency  frequency   monetary
# 0            11000      238          7  4600.4296
# 1            11001       18         10  2758.6280
# 2            11002      307          3  4466.8124
# 3            11003      231          8  4493.0624
# 4            11004      240          5  4546.1038
# ...            ...      ...        ...        ...
# 17411        29479      479          1  2049.0982
# 17412        29480      163          5  2440.3384
# 17413        29481      868          1  3374.9900
# 17414        29482      465          1  2049.0982
# 17415        29483      474          1  2049.0982
#
# [17416 rows x 4 columns]

# %%
import sklearn

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
wcss=[]
silhouettescore=[]
for i in range(2,30):
    kmeans=KMeans(n_clusters=i,init='k-means++')
    kmeans.fit(rfm.drop('CustomerKey',axis=1))
    wcss.append(kmeans.inertia_)
    silhouettescore.append(silhouette_score(rfm.drop('CustomerKey',axis=1),kmeans.predict(rfm.drop('CustomerKey',axis=1))))

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(range(2,30),wcss,marker='o',linestyle='--')
plt.grid()
plt.show()

# %%
## From the WCSS above we can see that the number of clusters is 3,4,5

# %%
plt.plot(range(2,30),silhouettescore,marker='o',linestyle='--')
plt.grid()
plt.show()

# %%
#From the silhouette score above we can see the one with the highest silhouette score is for 3 clusters

# %%
#Basis the WCSS score and silhouette score we can take the number of clusters to be 3

# %%
kmeans=KMeans(n_clusters=3,init='k-means++')
kmeans.fit(rfm.drop('CustomerKey',axis=1))
kmeans.labels_
# Out:
# array([1, 2, 1, ..., 2, 2, 2])

# %%
rfm['Cluster']=kmeans.labels_

# %%
rfm.drop('CustomerKey',axis=1).groupby('Cluster').mean()
# Out:
#             recency  frequency     monetary
# Cluster
# 0        155.448875   2.848425   227.486571
# 1        139.524380   4.843725  5269.176861
# 2        178.190852   3.228444  2337.439466

# %%
rfm['Cluster']=rfm['Cluster'].replace({0:'Moderate Value Customers',1:'Low Frequency and Low Value Customers',2:'High Value Customers'})

# %%
rfm
# Out:
#        CustomerKey  recency  frequency   monetary  \
# 0            11000      238          7  4600.4296
# 1            11001       18         10  2758.6280
# 2            11002      307          3  4466.8124
# 3            11003      231          8  4493.0624
# 4            11004      240          5  4546.1038
# ...            ...      ...        ...        ...
# 17411        29479      479          1  2049.0982
# 17412        29480      163          5  2440.3384
# 17413        29481      868          1  3374.9900
# 17414        29482      465          1  2049.0982
# 17415        29483      474          1  2049.0982
#
#                                      Cluster
# 0      Low Frequency and Low Value Customers
# 1                       High Value Customers
# 2      Low Frequency and Low Value Customers
# 3      Low Frequency and Low Value Customers
# 4      Low Frequency and Low Value Customers
# ...                                      ...
# 17411                   High Value Customers
# 17412                   High Value Customers
# 17413                   High Value Customers
# 17414                   High Value Customers
# 17415                   High Value Customers
#
# [17416 rows x 5 columns]

# %%
customer['CustomerKey']=customer['CustomerKey'].astype('int')

# %%
rfm['CustomerKey']=rfm['CustomerKey'].astype('int')

# %%
customer=customer.merge(rfm,how='inner',on='CustomerKey')

# %%
customer['BirthDate']=pd.to_datetime(customer['BirthDate'])

# %%
customer['Age']=round((max_date-customer['BirthDate']).dt.days/365,0)

# %%
customer['MaritalStatus']=customer['MaritalStatus'].str.strip()

# %%
customer.columns
# Out:
# Index(['CustomerKey', 'BirthDate', 'MaritalStatus', 'Gender', 'EmailAddress',
#        'AnnualIncome', 'TotalChildren', 'EducationLevel', 'Occupation',
#        'HomeOwner', 'name', 'recency', 'frequency', 'monetary', 'Cluster',
#        'Age'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#customer['MaritalStatus']=LabelEncoder().fit_transform(customer['MaritalStatus'])

# %%
customer['MaritalStatus']=customer['MaritalStatus'].replace({1:'M',0:'S'})

# %%
from collections import Counter

# %%
Counter(customer['MaritalStatus'])
# Out:
# Counter({'M': 9373, 'S': 7920})

# %%
customer
# Out:
#        CustomerKey  BirthDate MaritalStatus Gender  \
# 0            11000 1966-04-08             M      M
# 1            11001 1965-05-14             S      M
# 2            11002 1965-08-12             M      M
# 3            11003 1968-02-15             S      F
# 4            11004 1968-08-08             S      F
# ...            ...        ...           ...    ...
# 17288        29479 1958-07-04             M      M
# 17289        29480 1960-11-10             S      F
# 17290        29481 1960-01-05             S      M
# 17291        29482 1959-03-05             M      M
# 17292        29483 1959-12-08             M      M
#
#                          EmailAddress  AnnualIncome  TotalChildren  \
# 0           jon24@adventure-works.com       90000.0            2.0
# 1        eugene10@adventure-works.com       60000.0            3.0
# 2         ruben35@adventure-works.com       60000.0            3.0
# 3       christy12@adventure-works.com       70000.0            0.0
# 4      elizabeth5@adventure-works.com       80000.0            5.0
# ...                               ...           ...            ...
# 17288      tommy2@adventure-works.com       30000.0            1.0
# 17289      nina21@adventure-works.com       30000.0            3.0
# 17290       ivan0@adventure-works.com       30000.0            3.0
# 17291    clayton0@adventure-works.com       30000.0            3.0
# 17292      jésus9@adventure-works.com       30000.0            0.0
#
#         EducationLevel    Occupation HomeOwner               name  recency  \
# 0            Bachelors  Professional         Y           JON YANG      238
# 1            Bachelors  Professional         N       EUGENE HUANG       18
# 2            Bachelors  Professional         Y       RUBEN TORRES      307
# 3            Bachelors  Professional         N        CHRISTY ZHU      231
# 4            Bachelors  Professional         Y  ELIZABETH JOHNSON      240
# ...                ...           ...       ...                ...      ...
# 17288  Graduate Degree      Clerical         Y         TOMMY TANG      479
# 17289  Graduate Degree      Clerical         Y          NINA RAJI      163
# 17290  Graduate Degree      Clerical         N          IVAN SURI      868
# 17291        Bachelors      Clerical         Y      CLAYTON ZHANG      465
# 17292        Bachelors      Clerical         Y      JÉSUS NAVARRO      474
#
#        frequency   monetary                                Cluster   Age
# 0              7  4600.4296  Low Frequency and Low Value Customers  56.0
# 1             10  2758.6280                   High Value Customers  57.0
# 2              3  4466.8124  Low Frequency and Low Value Customers  57.0
# 3              8  4493.0624  Low Frequency and Low Value Customers  54.0
# 4              5  4546.1038  Low Frequency and Low Value Customers  54.0
# ...          ...        ...                                    ...   ...
# 17288          1  2049.0982                   High Value Customers  64.0
# 17289          5  2440.3384                   High Value Customers  62.0
# 17290          1  3374.9900                   High Value Customers  63.0
# 17291          1  2049.0982                   High Value Customers  63.0
# 17292          1  2049.0982                   High Value Customers  63.0
#
# [17293 rows x 16 columns]

# %%
rfm.drop('CustomerKey',axis=1).groupby('Cluster').mean()
# Out:
#                                           recency  frequency     monetary
# Cluster
# High Value Customers                   178.190852   3.228444  2337.439466
# Low Frequency and Low Value Customers  139.524380   4.843725  5269.176861
# Moderate Value Customers               155.448875   2.848425   227.486571
